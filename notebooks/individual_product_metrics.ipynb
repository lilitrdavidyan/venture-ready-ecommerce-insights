# %% [markdown]
# This notebook introduces various metrics that will be used for product performance analysis and evaluation. Below are the key metrics that will be discussed:
#
#
# ### Total Sales (`total_sales`):
# - **Definition:** The sum of the 'sales' column across the dataset.
# - **Purpose:** Provides a baseline to understand the overall revenue generated from the products.
#
# ### Total Profit (`total_profit`):
# - **Definition:** The sum of the 'profit' column across the dataset.
# - **Purpose:** Indicates the total earnings.
#
# ### Total Units Sold (`total_units_sold`):
# - **Definition:** Sum of the 'quantity' sold per product.
# - **Purpose:** Measures the volume of products sold, useful for sales performance analysis.
#
# ### Average Sale Price (`average_sale_price`):
# - **Definition:** Average of the 'sales' values per product.
# - **Purpose:** Helps understand the typical selling price per order, useful for pricing strategies.
#
# ### Average Discount (`average_discount`):
# - **Definition:** Average of the 'discount' provided per product.
# - **Purpose:** Indicates how much discount is typically given, which can affect profitability and sales strategies.
#
# ### Average Processing Time (`average_processing_time`):
# - **Definition:** Average processing time per product.
# - **Purpose:** Useful for assessing operational efficiency and customer service quality.
#
# ### Total Returns (`total_returns`):
# - **Definition:** Sum of negative quantities for each product group, indicating returned items.
# - **Purpose:** Highlights product return rates which can inform quality issues or customer satisfaction problems.
#
# ### Total Loss (`total_loss`):
# - **Definition:** Sum of negative profit values, indicating financial losses from returns or other factors.
# - **Purpose:** Identifies loss-making aspects of the product portfolio.
#
# ### Profit Margin (`profit_margin`):
# - **Definition:** Calculated as (Total Profit / Total Sales) * 100 for each product.
# - **Purpose:** Shows the profitability percentage, indicating how much of the sales convert into profit.
#
# ### Average Profit Per Unit (`average_profit_per_unit`):
# - **Definition:** Calculated by dividing total profit by total units sold per product.
# - **Purpose:** Assesses how much profit is made per unit sold, helping in evaluating product performance.
#
# ### Sales Percentage of Total (`sales_percentage_of_total`):
# - **Definition:** (Total Sales of a product / Total Sales of all products) * 100.
# - **Purpose:** Indicates the contribution of each product's sales to the overall sales, useful for identifying key revenue drivers.
#
# ### Profit Rank (`profit_rank`) and Sales Rank (`sales_rank`):
# - **Definition:** These ranks are calculated based on the descending order of total profit and total sales, respectively.
# - **Purpose:** Helps in quickly identifying top-performing products in terms of profitability and sales volume.
#
# ### Discount Impact on Sales (`discount_impact_on_sales`):
# - **Definition:** Calculated as the percentage change in total sales for each product relative to the average sales of products with the lowest 10% of discounts.
# - **Purpose:** Measures how variations in discount levels influence sales compared to a baseline, providing insights into the effectiveness of discount strategies.
#
# ### Discount Impact on Profit (`discount_impact_on_profit`):
# - **Definition:** Calculated as the percentage change in total profit for each product relative to the average profit of products with the lowest 10% of discounts.
# - **Purpose:** Evaluates the impact of discounts on profitability, helping to assess whether discount strategies are enhancing or harming overall financial performance.
#
# ### Active Months (`active_months`):
# - **Definition:** The count of unique year-month combinations during which each product was sold, derived from the order dates.
# - **Purpose:** Indicates the duration of active sales for each product, providing a measure of product lifespan and market presence.
#
# ### Composite Score (`composite_score`):
# - **Definition:** A combined score derived by summing the normalized values of sales, adjusted profit, profit margin, and active months for each product.
# - **Purpose:** Provides a single, holistic measure of product performance that incorporates financial success, pricing efficiency, market engagement, and profitability adjustments, aiding in comprehensive product evaluation and decision-making.
#
# These metrics serve different purposes and collectively contribute to a comprehensive analysis of product performance and financial success.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.preprocessing import MinMaxScaler

# %%
# Set option to display all columns of the DataFrame
pd.set_option('display.max_columns', None)

# %%
data_path = '../data/cleaned_ecommerce.csv'

try:
    data = pd.read_csv(data_path, encoding='utf-8')
except UnicodeDecodeError:
    data = pd.read_csv(data_path, encoding='ISO-8859-1')  # Using ISO-8859-1 if UTF-8 fails

# %%
data
# Out:
#             order_id date_ordered date_shipped       ship_mode customer_id  \
# 0     CA-2016-152156   2016-11-08   2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156   2016-11-08   2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688   2016-06-12   2016-06-16    Second Class    DV-13045
# 3     US-2015-108966   2015-10-11   2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966   2015-10-11   2015-10-18  Standard Class    SO-20335
# ...              ...          ...          ...             ...         ...
# 9933  CA-2014-110422   2014-01-21   2014-01-23    Second Class    TB-21400
# 9934  CA-2017-121258   2017-02-26   2017-03-03  Standard Class    DB-13060
# 9935  CA-2017-121258   2017-02-26   2017-03-03  Standard Class    DB-13060
# 9936  CA-2017-121258   2017-02-26   2017-03-03  Standard Class    DB-13060
# 9937  CA-2017-119914   2017-05-04   2017-05-09    Second Class    CC-12220
#
#         segment             city       state  postal_code region  \
# 0      Consumer        Henderson    Kentucky        42420  South
# 1      Consumer        Henderson    Kentucky        42420  South
# 2     Corporate      Los Angeles  California        90036   West
# 3      Consumer  Fort Lauderdale     Florida        33311  South
# 4      Consumer  Fort Lauderdale     Florida        33311  South
# ...         ...              ...         ...          ...    ...
# 9933   Consumer            Miami     Florida        33180  South
# 9934   Consumer       Costa Mesa  California        92627   West
# 9935   Consumer       Costa Mesa  California        92627   West
# 9936   Consumer       Costa Mesa  California        92627   West
# 9937   Consumer      Westminster  California        92683   West
#
#            product_id         category  subcategory  \
# 0     FUR-BO-10001798        Furniture    Bookcases
# 1     FUR-CH-10000454        Furniture       Chairs
# 2     OFF-LA-10000240  Office Supplies       Labels
# 3     FUR-TA-10000577        Furniture       Tables
# 4     OFF-ST-10000760  Office Supplies      Storage
# ...               ...              ...          ...
# 9933  FUR-FU-10001889        Furniture  Furnishings
# 9934  FUR-FU-10000747        Furniture  Furnishings
# 9935  TEC-PH-10003645       Technology       Phones
# 9936  OFF-PA-10004041  Office Supplies        Paper
# 9937  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name     sales  quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9933                             Ultra Door Pull Handle   25.2480         3
# 9934  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9935                              Aastra 57i VoIP phone  258.5760         2
# 9936  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9937  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       discount    profit  processing_time
# 0         0.00   41.9136                3
# 1         0.00  219.5820                3
# 2         0.00    6.8714                4
# 3         0.45 -383.0310                7
# 4         0.20    2.5164                7
# ...        ...       ...              ...
# 9933      0.20    4.1028                2
# 9934      0.00   15.6332                5
# 9935      0.20   19.3932                5
# 9936      0.00   13.3200                5
# 9937      0.00   72.9480                5
#
# [9938 rows x 19 columns]

# %% [markdown]
# ### 1. Standardize on the Most Common Product Name

# %%
# Group by 'product_id' and 'product_name', and count occurrences
name_counts = data.groupby(['product_id', 'product_name']).size().reset_index(name='count')

# Sort the results and keep the most common name for each product_id
most_common_names = name_counts.sort_values(by=['product_id', 'count'], ascending=[True, False]).drop_duplicates('product_id')

# Merge this back to the original data to standardize the product names
standardized_data = data.merge(most_common_names[['product_id', 'product_name']], on='product_id', suffixes=('', '_standardized'))

# Use the standardized product name for further analysis
standardized_data['product_name'] = standardized_data['product_name_standardized']
standardized_data.drop(columns=['product_name_standardized'], inplace=True)

standardized_data
# Out:
#             order_id date_ordered date_shipped       ship_mode customer_id  \
# 0     CA-2016-152156   2016-11-08   2016-11-11    Second Class    CG-12520
# 1     CA-2016-117681   2016-04-09   2016-04-14  Standard Class    HF-14995
# 2     CA-2017-159793   2017-08-25   2017-08-29  Standard Class    SV-20365
# 3     CA-2017-110198   2017-05-01   2017-05-02     First Class    AG-10900
# 4     CA-2016-152156   2016-11-08   2016-11-11    Second Class    CG-12520
# ...              ...          ...          ...             ...         ...
# 9933  CA-2014-169446   2014-12-19   2014-12-25  Standard Class    SG-20605
# 9934  CA-2016-129280   2016-05-03   2016-05-05     First Class    SM-20905
# 9935  CA-2015-138625   2015-11-02   2015-11-05     First Class    EG-13900
# 9936  CA-2016-114867   2016-12-23   2016-12-28  Standard Class    FM-14290
# 9937  CA-2016-114405   2016-04-07   2016-04-12  Standard Class    AS-10240
#
#           segment           city         state  postal_code   region  \
# 0        Consumer      Henderson      Kentucky        42420    South
# 1        Consumer    Los Angeles    California        90004     West
# 2        Consumer   Philadelphia  Pennsylvania        19140     East
# 3        Consumer  Coral Springs       Florida        33065    South
# 4        Consumer      Henderson      Kentucky        42420    South
# ...           ...            ...           ...          ...      ...
# 9933     Consumer        Chicago      Illinois        60623  Central
# 9934     Consumer         Newark          Ohio        43055     East
# 9935     Consumer     Chesapeake      Virginia        23320    South
# 9936  Home Office   Philadelphia  Pennsylvania        19143     East
# 9937     Consumer   Philadelphia  Pennsylvania        19120     East
#
#            product_id         category subcategory  \
# 0     FUR-BO-10001798        Furniture   Bookcases
# 1     FUR-BO-10001798        Furniture   Bookcases
# 2     FUR-BO-10001798        Furniture   Bookcases
# 3     FUR-BO-10001798        Furniture   Bookcases
# 4     FUR-CH-10000454        Furniture      Chairs
# ...               ...              ...         ...
# 9933  TEC-PH-10002817       Technology      Phones
# 9934  TEC-MA-10003589       Technology    Machines
# 9935  OFF-AP-10003099  Office Supplies  Appliances
# 9936  TEC-PH-10002645       Technology      Phones
# 9937  OFF-ST-10001627  Office Supplies     Storage
#
#                                            product_name     sales  quantity  \
# 0                     Bush Somerset Collection Bookcase   261.960         2
# 1                     Bush Somerset Collection Bookcase   556.665         5
# 2                     Bush Somerset Collection Bookcase   130.980         2
# 3                     Bush Somerset Collection Bookcase   314.352         3
# 4     Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.940         3
# ...                                                 ...       ...       ...
# 9933                    RCA ViSYS 25425RE1 Corded phone   323.976         3
# 9934                       Cisco 8961 IP Phone Charcoal   224.937         3
# 9935                        Eureka Hand Vacuum, Bagless   197.720         4
# 9936                                              LG G2  1499.970         5
# 9937  Eldon Jumbo ProFile Portable File Boxes Graphi...    36.744         3
#
#       discount    profit  processing_time
# 0         0.00   41.9136                3
# 1         0.15    6.5490                5
# 2         0.50  -89.0664                4
# 3         0.20  -15.7176                1
# 4         0.00  219.5820                3
# ...        ...       ...              ...
# 9933      0.20   36.4473                6
# 9934      0.70 -164.9538                2
# 9935      0.00   55.3616                3
# 9936      0.40 -374.9925                5
# 9937      0.20    3.6744                5
#
# [9938 rows x 19 columns]

# %%
data = standardized_data

# %%
# Calculate the sale price per unit for each transaction
data['sale_price_per_unit'] = data['sales'] / data['quantity']

# Calculate total metrics for perspective
total_sales = data['sales'].sum()
total_profit = data['profit'].sum()

# Group data by 'product_id' and 'product_name' to calculate the desired metrics
product_metrics = data.dropna().groupby(['product_id', 'product_name', 'category', 'subcategory']).agg(
    total_sales=('sales', 'sum'),
    total_units_sold=('quantity', 'sum'),
    average_sale_price=('sales', 'mean'),
    min_sale_price_per_unit=('sale_price_per_unit', 'min'),  # Minimum sale price per unit
    max_sale_price_per_unit=('sale_price_per_unit', 'max'),  # Maximum sale price per unit
    avg_sale_price_per_unit=('sale_price_per_unit', 'mean'),  # Mean sale price per unit
    total_profit=('profit', 'sum'),
    average_discount=('discount', 'mean'),
    average_processing_time=('processing_time', 'mean'),
    total_returns=('quantity', lambda x: x[x < 0].sum()),  # Summing only negative quantities
    total_loss=('profit', lambda x: x[x < 0].sum())  # Summing only negative profit
).reset_index()

# Calculate Profit Margin as a percentage
product_metrics['profit_margin'] = product_metrics['total_profit'] / product_metrics['total_sales'] * 100

# Recalculate Total Orders and merge correctly with the product metrics
order_counts = data.groupby('product_id')['order_id'].nunique().reset_index()
product_metrics = product_metrics.merge(order_counts, on='product_id', how='left')
product_metrics.rename(columns={'order_id': 'total_orders'}, inplace=True)

# Additional KPIs
product_metrics['average_profit_per_unit'] = product_metrics['total_profit'] / product_metrics['total_units_sold']
product_metrics['sales_percentage_of_total'] = product_metrics['total_sales'] / total_sales * 100
product_metrics['profit_rank'] = product_metrics['total_profit'].rank(ascending=False)
product_metrics['sales_rank'] = product_metrics['total_sales'].rank(ascending=False)

product_metrics
# Out:
#            product_id                                       product_name  \
# 0     FUR-BO-10000112   Bush Birmingham Collection Bookcase, Dark Cherry
# 1     FUR-BO-10000330  Sauder Camden County Barrister Bookcase, Plank...
# 2     FUR-BO-10000362                 Sauder Inglewood Library Bookcases
# 3     FUR-BO-10000468            O'Sullivan 2-Shelf Heavy-Duty Bookcases
# 4     FUR-BO-10000711                          Hon Metal Bookcases, Gray
# ...               ...                                                ...
# 1855  TEC-PH-10004912                  Cisco SPA112 2 Port Phone Adapter
# 1856  TEC-PH-10004922             RCA Visys Integrated PBX 8-Line Router
# 1857  TEC-PH-10004924  SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x...
# 1858  TEC-PH-10004959             Classic Ivory Antique Telephone ZL1810
# 1859  TEC-PH-10004977                                        GE 30524EE4
#
#         category subcategory  total_sales  total_units_sold  \
# 0      Furniture   Bookcases      825.174                 9
# 1      Furniture   Bookcases     1064.624                10
# 2      Furniture   Bookcases     2154.348                14
# 3      Furniture   Bookcases      723.842                21
# 4      Furniture   Bookcases      851.760                12
# ...          ...         ...          ...               ...
# 1855  Technology      Phones      516.530                11
# 1856  Technology      Phones     1085.238                19
# 1857  Technology      Phones       56.164                 8
# 1858  Technology      Phones      341.666                 4
# 1859  Technology      Phones     5291.730                32
#
#       average_sale_price  min_sale_price_per_unit  max_sale_price_per_unit  \
# 0             825.174000                   91.686                   91.686
# 1             354.874667                  102.833                  120.980
# 2             430.869600                  119.686                  170.980
# 3             120.640333                   14.574                   48.580
# 4             425.880000                   70.980                   70.980
# ...                  ...                      ...                      ...
# 1855          172.176667                   43.960                   54.950
# 1856          217.047600                   53.592                   66.990
# 1857           18.721333                    5.912                    7.390
# 1858          170.833000                   80.392                  100.490
# 1859          587.970000                  117.594                  195.990
#
#       avg_sale_price_per_unit  total_profit  average_discount  \
# 0                   91.686000     -117.8820          0.300000
# 1                  108.882000       24.1960          0.100000
# 2                  148.752600      311.1836          0.130000
# 3                   39.673667     -133.1092          0.183333
# 4                   70.980000      229.9752          0.000000
# ...                       ...           ...               ...
# 1855                47.623333       87.3705          0.133333
# 1856                58.951200      130.6305          0.120000
# 1857                 6.897333       13.0064          0.066667
# 1858                90.441000       40.1960          0.100000
# 1859               165.502667      838.8372          0.155556
#
#       average_processing_time  total_returns  total_loss  profit_margin  \
# 0                    2.000000              0   -117.8820     -14.285714
# 1                    1.666667              0     -9.6784       2.272727
# 2                    4.000000              0    -35.9058      14.444444
# 3                    3.666667              0   -195.2916     -18.389262
# 4                    6.500000              0      0.0000      27.000000
# ...                       ...            ...         ...            ...
# 1855                 3.333333              0      0.0000      16.914894
# 1856                 4.000000              0      0.0000      12.037037
# 1857                 2.333333              0      0.0000      23.157895
# 1858                 3.000000              0      0.0000      11.764706
# 1859                 2.666667              0    -43.1178      15.851852
#
#       total_orders  average_profit_per_unit  sales_percentage_of_total  \
# 0                1               -13.098000                   0.036223
# 1                3                 2.419600                   0.046735
# 2                5                22.227400                   0.094571
# 3                6                -6.338533                   0.031775
# 4                2                19.164600                   0.037391
# ...            ...                      ...                        ...
# 1855             3                 7.942773                   0.022675
# 1856             5                 6.875289                   0.047640
# 1857             3                 1.625800                   0.002465
# 1858             2                10.049000                   0.014998
# 1859             9                26.213662                   0.232296
#
#       profit_rank  sales_rank
# 0          1740.0       570.0
# 1          1152.0       499.0
# 2           268.0       283.0
# 3          1751.0       602.0
# 4           337.0       560.0
# ...           ...         ...
# 1855        639.0       723.0
# 1856        481.0       491.0
# 1857       1351.0      1603.0
# 1858        974.0       882.0
# 1859         89.0       101.0
#
# [1860 rows x 21 columns]

# %%
product_metrics[product_metrics['total_returns']!=0]
# Out:
#           product_id                product_name   category subcategory  \
# 323  FUR-TA-10001039  KI Adjustable-Height Table  Furniture      Tables
# 361  FUR-TA-10004086  KI Adjustable-Height Table  Furniture      Tables
#
#      total_sales  total_units_sold  average_sale_price  \
# 323     2764.257               -47          251.296091
# 361     1788.384               -27          255.483429
#
#      min_sale_price_per_unit  max_sale_price_per_unit  \
# 323                   -85.98                   -42.99
# 361                   -85.98                   -42.99
#
#      avg_sale_price_per_unit  total_profit  average_discount  \
# 323               -66.829909     -226.1274          0.222727
# 361               -63.870857      -22.3548          0.257143
#
#      average_processing_time  total_returns  total_loss  profit_margin  \
# 323                 3.636364            -47   -494.3850      -8.180404
# 361                 4.285714            -27   -216.6696      -1.250000
#
#      total_orders  average_profit_per_unit  sales_percentage_of_total  \
# 323            11                 4.811221                   0.121345
# 361             7                 0.827956                   0.078506
#
#      profit_rank  sales_rank
# 323       1780.0       219.0
# 361       1666.0       328.0

# %%
data[data['product_id']=='FUR-TA-10001039']
# Out:
#             order_id date_ordered date_shipped       ship_mode customer_id  \
# 6001  US-2014-118486   2014-04-06   2014-04-08     First Class    SD-20485
# 6002  CA-2015-112116   2015-03-16   2015-03-18    Second Class    JE-15475
# 6003  CA-2014-104283   2014-06-27   2014-07-01  Standard Class    LM-17065
# 6004  CA-2017-148404   2017-10-07   2017-10-11  Standard Class    Dp-13240
# 6005  CA-2014-160766   2014-09-14   2014-09-14        Same Day    DM-13015
# 6006  CA-2014-117765   2014-09-07   2014-09-13  Standard Class    RB-19465
# 6007  CA-2017-135937   2017-02-20   2017-02-27  Standard Class    KM-16375
# 6008  CA-2017-141439   2017-11-26   2017-12-01  Standard Class    TT-21460
# 6009  CA-2016-104276   2016-11-27   2016-12-03  Standard Class    HF-14995
# 6010  CA-2017-125451   2017-10-23   2017-10-24     First Class    AH-10075
# 6011  US-2015-151435   2015-09-06   2015-09-09    Second Class    SW-20455
#
#           segment             city           state  postal_code   region  \
# 6001  Home Office     Philadelphia    Pennsylvania        19143     East
# 6002     Consumer          Seattle      Washington        98103     West
# 6003     Consumer        Southaven     Mississippi        38671    South
# 6004  Home Office        Charlotte  North Carolina        28205    South
# 6005     Consumer    New York City        New York        10009     East
# 6006  Home Office            Tulsa        Oklahoma        74133  Central
# 6007  Home Office          Gilbert         Arizona        85234     West
# 6008  Home Office         Richmond         Indiana        47374  Central
# 6009     Consumer  Fort Lauderdale         Florida        33311    South
# 6010    Corporate         Cranston    Rhode Island         2920     East
# 6011     Consumer        Lafayette       Louisiana        70506    South
#
#            product_id   category subcategory                product_name  \
# 6001  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
# 6002  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
# 6003  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
# 6004  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
# 6005  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
# 6006  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
# 6007  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
# 6008  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
# 6009  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
# 6010  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
# 6011  FUR-TA-10001039  Furniture      Tables  KI Adjustable-Height Table
#
#         sales  quantity  discount    profit  processing_time  \
# 6001  154.764        -3      0.40  -36.1116                2
# 6002  171.960        -2      0.00   44.7096                2
# 6003   85.980        -1      0.00   22.3548                4
# 6004  154.764        -3      0.40  -36.1116                4
# 6005  464.292        -9      0.40 -108.3348                0
# 6006  429.900        -5      0.00  111.7740                6
# 6007  386.910        -9      0.50 -185.7168                7
# 6008  257.940        -3      0.00   67.0644                5
# 6009  331.023        -7      0.45 -114.3534                6
# 6010  240.744        -4      0.30  -13.7568                1
# 6011   85.980        -1      0.00   22.3548                3
#
#       sale_price_per_unit
# 6001              -51.588
# 6002              -85.980
# 6003              -85.980
# 6004              -51.588
# 6005              -51.588
# 6006              -85.980
# 6007              -42.990
# 6008              -85.980
# 6009              -47.289
# 6010              -60.186
# 6011              -85.980

# %%
data[data['order_id']=='CA-2016-104276']
# Out:
#             order_id date_ordered date_shipped       ship_mode customer_id  \
# 6009  CA-2016-104276   2016-11-27   2016-12-03  Standard Class    HF-14995
# 7670  CA-2016-104276   2016-11-27   2016-12-03  Standard Class    HF-14995
#
#        segment             city    state  postal_code region       product_id  \
# 6009  Consumer  Fort Lauderdale  Florida        33311  South  FUR-TA-10001039
# 7670  Consumer  Fort Lauderdale  Florida        33311  South  TEC-PH-10001944
#
#         category subcategory  \
# 6009   Furniture      Tables
# 7670  Technology      Phones
#
#                                           product_name    sales  quantity  \
# 6009                        KI Adjustable-Height Table  331.023        -7
# 7670  Wi-Ex zBoost YX540 Cellular Phone Signal Booster  116.760         1
#
#       discount    profit  processing_time  sale_price_per_unit
# 6009      0.45 -114.3534                6              -47.289
# 7670      0.20   14.5950                6              116.760

# %%
# Calculate correlation between discount and sales
discount_sales_correlation = np.corrcoef(product_metrics['average_discount'], product_metrics['total_sales'])[0, 1]

# Calculate correlation between discount and profitability
discount_profit_correlation = np.corrcoef(product_metrics['average_discount'], product_metrics['profit_margin'])[0, 1]

print("Discount and Sales Correlation:", discount_sales_correlation)
print("Discount and Profitability Correlation:", discount_profit_correlation)
# Out:
# Discount and Sales Correlation: 0.07077440070375345
# Discount and Profitability Correlation: -0.6651633050209477

# %% [markdown]
# **1. Impact on Sales:**
#
# **Observation**: There is a very weak positive correlation between discounts and sales volumes (Correlation Coefficient: 0.073).
# **Implication**: Based on the available data, discounts have minimal impact on increasing the sales volumes. This suggests that customers' purchasing decisions might not be heavily influenced by price reductions.
# **Recommendation**: Consider exploring alternative sales promotion tactics beyond discounts, such as improving products, enhancing customer service, or investing in marketing campaigns that highlight the unique selling propositions.
#
# **2. Impact on Profitability:**
#
# **Observation:** There is a moderate to strong negative correlation between discounts and profitability (Correlation Coefficient: **-0.664**).
# **Implication:** Based on the available data, higher discounts significantly reduce the profit margins. This underscores the cost of discounts as a sales strategy.
# **Recommendation:** Reevaluate our discount strategy to focus on more targeted, strategic discounting that maintains or improves profitability. This might include selective discounts for high-margin products or bundled offerings that encourage larger purchase sizes without eroding profit margins.
#
# **Conclusion:**
# While discounts are a common tactic to attract customers, the data suggests that their effectiveness in boosting sales is limited, and they pose a risk to the profitability. A shift towards more strategic discounting, coupled with alternative promotional activities, could better serve the long-term growth and profitability goals.

# %%
# Assuming a minimal baseline discount for comparison (e.g., the lowest 10% of discounts)
baseline_discount = product_metrics['average_discount'].quantile(0.1)
baseline_sales = product_metrics[product_metrics['average_discount'] <= baseline_discount]['total_sales'].mean()
baseline_profit = product_metrics[product_metrics['average_discount'] <= baseline_discount]['total_profit'].mean()

# Calculate discount impact on sales and profit as percentage change from the baseline
product_metrics['discount_impact_on_sales'] = (product_metrics['total_sales'] - baseline_sales) / baseline_sales * 100
product_metrics['discount_impact_on_profit'] = (product_metrics['total_profit'] - baseline_profit) / baseline_profit * 100

product_metrics[['product_id', 'product_name', 'average_discount', 'total_sales', 'discount_impact_on_sales','total_profit', 'discount_impact_on_profit']]
# Out:
#            product_id                                       product_name  \
# 0     FUR-BO-10000112   Bush Birmingham Collection Bookcase, Dark Cherry
# 1     FUR-BO-10000330  Sauder Camden County Barrister Bookcase, Plank...
# 2     FUR-BO-10000362                 Sauder Inglewood Library Bookcases
# 3     FUR-BO-10000468            O'Sullivan 2-Shelf Heavy-Duty Bookcases
# 4     FUR-BO-10000711                          Hon Metal Bookcases, Gray
# ...               ...                                                ...
# 1855  TEC-PH-10004912                  Cisco SPA112 2 Port Phone Adapter
# 1856  TEC-PH-10004922             RCA Visys Integrated PBX 8-Line Router
# 1857  TEC-PH-10004924  SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x...
# 1858  TEC-PH-10004959             Classic Ivory Antique Telephone ZL1810
# 1859  TEC-PH-10004977                                        GE 30524EE4
#
#       average_discount  total_sales  discount_impact_on_sales  total_profit  \
# 0             0.300000      825.174                 35.841523     -117.8820
# 1             0.100000     1064.624                 75.260182       24.1960
# 2             0.130000     2154.348                254.652369      311.1836
# 3             0.183333      723.842                 19.160080     -133.1092
# 4             0.000000      851.760                 40.218155      229.9752
# ...                ...          ...                       ...           ...
# 1855          0.133333      516.530                -14.967968       87.3705
# 1856          0.120000     1085.238                 78.653694      130.6305
# 1857          0.066667       56.164                -90.754188       13.0064
# 1858          0.100000      341.666                -43.754372       40.1960
# 1859          0.155556     5291.730                771.133438      838.8372
#
#       discount_impact_on_profit
# 0                   -156.782664
# 1                    -88.345012
# 2                     49.894247
# 3                   -164.117464
# 4                     10.776916
# ...                         ...
# 1855                 -57.914442
# 1856                 -37.076502
# 1857                 -93.734938
# 1858                 -80.637960
# 1859                 304.060082
#
# [1860 rows x 7 columns]

# %%
data['date_ordered'] = pd.to_datetime(data['date_ordered'])

# Extract year-month from the date_ordered and store in a new column
data['year_month'] = data['date_ordered'].dt.to_period('M')

# Group by 'product_id' and count unique year-month combinations
product_active_months = data.groupby('product_id')['year_month'].nunique().reset_index()

# Rename the column appropriately
product_active_months.rename(columns={'year_month': 'active_months'}, inplace=True)

# Merge this back into your original metrics DataFrame
product_metrics = product_metrics.merge(product_active_months, on='product_id', how='left')

# Show the DataFrame to verify
product_metrics
# Out:
#            product_id                                       product_name  \
# 0     FUR-BO-10000112   Bush Birmingham Collection Bookcase, Dark Cherry
# 1     FUR-BO-10000330  Sauder Camden County Barrister Bookcase, Plank...
# 2     FUR-BO-10000362                 Sauder Inglewood Library Bookcases
# 3     FUR-BO-10000468            O'Sullivan 2-Shelf Heavy-Duty Bookcases
# 4     FUR-BO-10000711                          Hon Metal Bookcases, Gray
# ...               ...                                                ...
# 1855  TEC-PH-10004912                  Cisco SPA112 2 Port Phone Adapter
# 1856  TEC-PH-10004922             RCA Visys Integrated PBX 8-Line Router
# 1857  TEC-PH-10004924  SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x...
# 1858  TEC-PH-10004959             Classic Ivory Antique Telephone ZL1810
# 1859  TEC-PH-10004977                                        GE 30524EE4
#
#         category subcategory  total_sales  total_units_sold  \
# 0      Furniture   Bookcases      825.174                 9
# 1      Furniture   Bookcases     1064.624                10
# 2      Furniture   Bookcases     2154.348                14
# 3      Furniture   Bookcases      723.842                21
# 4      Furniture   Bookcases      851.760                12
# ...          ...         ...          ...               ...
# 1855  Technology      Phones      516.530                11
# 1856  Technology      Phones     1085.238                19
# 1857  Technology      Phones       56.164                 8
# 1858  Technology      Phones      341.666                 4
# 1859  Technology      Phones     5291.730                32
#
#       average_sale_price  min_sale_price_per_unit  max_sale_price_per_unit  \
# 0             825.174000                   91.686                   91.686
# 1             354.874667                  102.833                  120.980
# 2             430.869600                  119.686                  170.980
# 3             120.640333                   14.574                   48.580
# 4             425.880000                   70.980                   70.980
# ...                  ...                      ...                      ...
# 1855          172.176667                   43.960                   54.950
# 1856          217.047600                   53.592                   66.990
# 1857           18.721333                    5.912                    7.390
# 1858          170.833000                   80.392                  100.490
# 1859          587.970000                  117.594                  195.990
#
#       avg_sale_price_per_unit  total_profit  average_discount  \
# 0                   91.686000     -117.8820          0.300000
# 1                  108.882000       24.1960          0.100000
# 2                  148.752600      311.1836          0.130000
# 3                   39.673667     -133.1092          0.183333
# 4                   70.980000      229.9752          0.000000
# ...                       ...           ...               ...
# 1855                47.623333       87.3705          0.133333
# 1856                58.951200      130.6305          0.120000
# 1857                 6.897333       13.0064          0.066667
# 1858                90.441000       40.1960          0.100000
# 1859               165.502667      838.8372          0.155556
#
#       average_processing_time  total_returns  total_loss  profit_margin  \
# 0                    2.000000              0   -117.8820     -14.285714
# 1                    1.666667              0     -9.6784       2.272727
# 2                    4.000000              0    -35.9058      14.444444
# 3                    3.666667              0   -195.2916     -18.389262
# 4                    6.500000              0      0.0000      27.000000
# ...                       ...            ...         ...            ...
# 1855                 3.333333              0      0.0000      16.914894
# 1856                 4.000000              0      0.0000      12.037037
# 1857                 2.333333              0      0.0000      23.157895
# 1858                 3.000000              0      0.0000      11.764706
# 1859                 2.666667              0    -43.1178      15.851852
#
#       total_orders  average_profit_per_unit  sales_percentage_of_total  \
# 0                1               -13.098000                   0.036223
# 1                3                 2.419600                   0.046735
# 2                5                22.227400                   0.094571
# 3                6                -6.338533                   0.031775
# 4                2                19.164600                   0.037391
# ...            ...                      ...                        ...
# 1855             3                 7.942773                   0.022675
# 1856             5                 6.875289                   0.047640
# 1857             3                 1.625800                   0.002465
# 1858             2                10.049000                   0.014998
# 1859             9                26.213662                   0.232296
#
#       profit_rank  sales_rank  discount_impact_on_sales  \
# 0          1740.0       570.0                 35.841523
# 1          1152.0       499.0                 75.260182
# 2           268.0       283.0                254.652369
# 3          1751.0       602.0                 19.160080
# 4           337.0       560.0                 40.218155
# ...           ...         ...                       ...
# 1855        639.0       723.0                -14.967968
# 1856        481.0       491.0                 78.653694
# 1857       1351.0      1603.0                -90.754188
# 1858        974.0       882.0                -43.754372
# 1859         89.0       101.0                771.133438
#
#       discount_impact_on_profit  active_months
# 0                   -156.782664              1
# 1                    -88.345012              3
# 2                     49.894247              5
# 3                   -164.117464              6
# 4                     10.776916              2
# ...                         ...            ...
# 1855                 -57.914442              3
# 1856                 -37.076502              5
# 1857                 -93.734938              3
# 1858                 -80.637960              2
# 1859                 304.060082              8
#
# [1860 rows x 24 columns]

# %%
# Summarize the top-selling products by total sales and total units sold
top_sales = product_metrics.nlargest(10, 'total_sales')[['product_name', 'category', 'subcategory', 'total_sales', 'total_profit', 'total_units_sold', 'active_months']]
top_units_sold = product_metrics.nlargest(10, 'total_units_sold')[['product_name', 'category', 'subcategory', 'total_sales', 'total_profit', 'total_units_sold', 'active_months']]
top_profits = product_metrics.nlargest(10, 'total_profit')[['product_name', 'category', 'subcategory', 'total_sales', 'total_profit', 'total_units_sold', 'active_months']]

# %% [markdown]
# ### Top-Selling Products by Total Sales

# %%
top_sales
# Out:
#                                            product_name         category  \
# 1614              Canon imageCLASS 2200 Advanced Copier       Technology
# 776   Fellowes PB500 Electric Punch Plastic Comb Bin...  Office Supplies
# 1641  Cisco TelePresence System EX90 Videoconferenci...       Technology
# 80         HON 5400 Series Task Chairs for Big and Tall        Furniture
# 691          GBC DocuBind TL300 Electric Binding System  Office Supplies
# 657    GBC Ibimaster 500 Manual ProClick Binding System  Office Supplies
# 1604               Hewlett Packard LaserJet 3310 Copier       Technology
# 1630  HP Designjet T520 Inkjet Large Format Printer ...       Technology
# 845           GBC DocuBind P400 Electric Binding System  Office Supplies
# 1420        High Speed Automatic Electric Letter Opener  Office Supplies
#
#      subcategory  total_sales  total_profit  total_units_sold  active_months
# 1614     Copiers    61599.824  2.519993e+04                20              5
# 776      Binders    27453.384  7.753039e+03                31             10
# 1641    Machines    22638.480 -1.811078e+03                 6              1
# 80        Chairs    21870.576  5.684342e-14                39              8
# 691      Binders    19823.479  2.233505e+03                37              9
# 657      Binders    19024.500  7.609800e+02                48              9
# 1604     Copiers    18839.686  6.983884e+03                38              7
# 1630    Machines    18374.895  4.094977e+03                12              3
# 845      Binders    17965.068 -1.878166e+03                27              6
# 1420    Supplies    17030.312 -2.620048e+02                11              2

# %% [markdown]
# ### Top-Selling Products by Units Sold

# %%
top_units_sold
# Out:
#                                            product_name         category  \
# 1569  Imation 16GB Mini TravelDrive USB 2.0 Flash Drive       Technology
# 1144                                         Xerox 1881  Office Supplies
# 694   GBC Premium Transparent Covers with Diagonal L...  Office Supplies
# 721                             Avery Arch Ring Binders  Office Supplies
# 93           Situations Contoured Folding Chairs, 4/Set        Furniture
# 325                  Chromcraft Round Conference Tables        Furniture
# 1517          Logitech G19 Programmable Gaming Keyboard       Technology
# 183                             DAX Wood Document Frame        Furniture
# 1548         Kingston Digital DataTraveler 16GB USB 2.0       Technology
# 1354                  Fellowes Officeware Wire Shelving  Office Supplies
#
#       subcategory  total_sales  total_profit  total_units_sold  active_months
# 1569  Accessories    11203.756     1987.9253                75             13
# 1144        Paper     2167.348     1006.4352                70             15
# 694       Binders      780.456       49.5128                67             11
# 721       Binders     2068.822      349.6332                64             10
# 93         Chairs     3499.314      198.7440                62             13
# 325        Tables     8209.059     -189.9761                61             11
# 1517  Accessories    13756.536     4425.3432                60             12
# 183   Furnishings      839.676      176.3247                57             13
# 1548  Accessories      477.930       64.7085                57             12
# 1354      Storage     4509.466     -332.3710                55             10

# %% [markdown]
# ### Top-Selling Products by Profit

# %%
top_profits
# Out:
#                                            product_name         category  \
# 1614              Canon imageCLASS 2200 Advanced Copier       Technology
# 776   Fellowes PB500 Electric Punch Plastic Comb Bin...  Office Supplies
# 1604               Hewlett Packard LaserJet 3310 Copier       Technology
# 1611                 Canon PC1060 Personal Laser Copier       Technology
# 1517          Logitech G19 Programmable Gaming Keyboard       Technology
# 1630  HP Designjet T520 Inkjet Large Format Printer ...       Technology
# 1665                  Ativa V4110MDD Micro-Cut Shredder       Technology
# 1629   3D Systems Cube Printer, 2nd Generation, Magenta       Technology
# 682                Ibico EPK-21 Electric Binding System  Office Supplies
# 1616                  Zebra ZM400 Thermal Label Printer       Technology
#
#       subcategory  total_sales  total_profit  total_units_sold  active_months
# 1614      Copiers    61599.824    25199.9280                20              5
# 776       Binders    27453.384     7753.0390                31             10
# 1604      Copiers    18839.686     6983.8836                38              7
# 1611      Copiers    11619.834     4570.9347                19              4
# 1517  Accessories    13756.536     4425.3432                60             12
# 1630     Machines    18374.895     4094.9766                12              3
# 1665     Machines     7699.890     3772.9461                11              2
# 1629     Machines    14299.890     3717.9714                11              2
# 682       Binders    15875.916     3345.2823                13              3
# 1616     Machines     6965.700     3343.5360                 6              1

# %% [markdown]
# ### Composite Score = (Normalized Total Sales) + (Normalized Total Profit) + (Normalized Profit Margin) + (Normalized Active Months)

# %%
# Selecting the relevant metrics
metrics = product_metrics[['product_id', 'product_name', 'total_sales', 'total_profit', 'profit_margin', 'active_months', 'category', 'subcategory']]


# Finding the minimum profit to adjust negative values
min_profit = product_metrics['total_profit'].min()


# Offset negative profits by adding the absolute value of the minimum profit + 1 to ensure all values are positive
profit_adjusted = product_metrics['total_profit'] + abs(min_profit) + 1

# Incorporate this adjusted profit into the normalized dataframe
metrics_adjusted = product_metrics[['total_sales', 'profit_margin', 'active_months']].copy()
metrics_adjusted['adjusted_profit'] = profit_adjusted

# Normalize the new metrics
scaler_adjusted = MinMaxScaler()
metrics_normalized_adjusted = scaler_adjusted.fit_transform(metrics_adjusted)
metrics_normalized_adjusted_df = pd.DataFrame(metrics_normalized_adjusted, columns=['normalized_sales', 'normalized_margin', 'normalized_adjusted_profit', 'normalized_active_months'])

# Calculate a new composite score with the adjusted profit
metrics_adjusted_combined = pd.concat([metrics, metrics_normalized_adjusted_df], axis=1)
metrics_adjusted_combined['composite_score'] = metrics_adjusted_combined['normalized_sales'] + metrics_adjusted_combined['normalized_adjusted_profit']+ metrics_adjusted_combined['normalized_margin']+ metrics_adjusted_combined['normalized_active_months']

# Merge the composite score back into the original DataFrame
product_metrics = product_metrics.merge(metrics_adjusted_combined[['product_id', 'composite_score']], on='product_id', how='left')

# Display the top products based on the new adjusted composite score
top_adjusted_composite_score_products = metrics_adjusted_combined.nlargest(10, 'composite_score')[['product_name', 'category', 'subcategory', 'total_sales', 'total_profit', 'profit_margin', 'active_months', 'composite_score']]
top_adjusted_composite_score_products
# Out:
#                                            product_name         category  \
# 1614              Canon imageCLASS 2200 Advanced Copier       Technology
# 776   Fellowes PB500 Electric Punch Plastic Comb Bin...  Office Supplies
# 1517          Logitech G19 Programmable Gaming Keyboard       Technology
# 1144                                         Xerox 1881  Office Supplies
# 1569  Imation 16GB Mini TravelDrive USB 2.0 Flash Drive       Technology
# 295       Eldon Image Series Desk Accessories, Burgundy        Furniture
# 1168  Adams Telephone Message Book W/Dividers/Space ...  Office Supplies
# 1604               Hewlett Packard LaserJet 3310 Copier       Technology
# 831                 Ibico Hi-Tech Manual Binding System  Office Supplies
# 1547  Plantronics CS510 - Over-the-Head monaural Wir...       Technology
#
#       subcategory  total_sales  total_profit  profit_margin  active_months  \
# 1614      Copiers    61599.824    25199.9280      40.909091              5
# 776       Binders    27453.384     7753.0390      28.240741             10
# 1517  Accessories    13756.536     4425.3432      32.169023             12
# 1144        Paper     2167.348     1006.4352      46.436253             15
# 1569  Accessories    11203.756     1987.9253      17.743383             13
# 295   Furnishings      426.560      116.7148      27.361872             15
# 1168        Paper     1004.652      415.2840      41.336104             14
# 1604      Copiers    18839.686     6983.8836      37.070064              7
# 831       Binders     5535.593     -246.0675      -4.445188             14
# 1547  Accessories    10822.360     3085.0325      28.506098             10
#
#       composite_score
# 1614         3.257742
# 776          2.509623
# 1517         2.344566
# 1144         2.314288
# 1569         2.258644
# 295          2.201231
# 1168         2.190946
# 1604         2.160099
# 831          2.104231
# 1547         2.103475

# %%
# Group data by category and display the top products based on the new adjusted composite score
top_products_by_category = metrics_adjusted_combined.groupby('category').apply(lambda x: x.nlargest(10, 'composite_score')).reset_index(drop=True)
top_products_by_category[['product_name', 'category', 'subcategory', 'total_sales', 'total_profit', 'profit_margin', 'active_months', 'composite_score']]
# Out:
#                                          product_name         category  \
# 0       Eldon Image Series Desk Accessories, Burgundy        Furniture
# 1                             DAX Wood Document Frame        Furniture
# 2          Situations Contoured Folding Chairs, 4/Set        Furniture
# 3         Global Value Mid-Back Manager's Chair, Gray        Furniture
# 4          Bretford Rectangular Conference Table Tops        Furniture
# 5                            SAFCO Arco Folding Chair        Furniture
# 6   Howard Miller 13-3/4" Diameter Brushed Chrome ...        Furniture
# 7                              Flat Face Poster Frame        Furniture
# 8        HON 5400 Series Task Chairs for Big and Tall        Furniture
# 9               DMI Eclipse Executive Suite Bookcases        Furniture
# 10  Fellowes PB500 Electric Punch Plastic Comb Bin...  Office Supplies
# 11                                         Xerox 1881  Office Supplies
# 12  Adams Telephone Message Book W/Dividers/Space ...  Office Supplies
# 13                Ibico Hi-Tech Manual Binding System  Office Supplies
# 14         GBC DocuBind TL300 Electric Binding System  Office Supplies
# 15  White Dual Perf Computer Printout Paper, 2700 ...  Office Supplies
# 16                                  Easy-staple paper  Office Supplies
# 17                           Avery File Folder Labels  Office Supplies
# 18   GBC Ibimaster 500 Manual ProClick Binding System  Office Supplies
# 19              Tennsco 6- and 18-Compartment Lockers  Office Supplies
# 20              Canon imageCLASS 2200 Advanced Copier       Technology
# 21          Logitech G19 Programmable Gaming Keyboard       Technology
# 22  Imation 16GB Mini TravelDrive USB 2.0 Flash Drive       Technology
# 23               Hewlett Packard LaserJet 3310 Copier       Technology
# 24  Plantronics CS510 - Over-the-Head monaural Wir...       Technology
# 25  Logitech 910-002974 M325 Wireless Mouse for We...       Technology
# 26         Kingston Digital DataTraveler 16GB USB 2.0       Technology
# 27           Wilson Electronics DB Pro Signal Booster       Technology
# 28                     Microsoft Sculpt Comfort Mouse       Technology
# 29   Nortel Meridian M3904 Professional Digital phone       Technology
#
#     subcategory  total_sales  total_profit  profit_margin  active_months  \
# 0   Furnishings     426.5600  1.167148e+02   2.736187e+01             15
# 1   Furnishings     839.6760  1.763247e+02   2.099914e+01             13
# 2        Chairs    3499.3140  1.987440e+02   5.679513e+00             13
# 3        Chairs    2442.0240  1.174863e+02   4.811022e+00             13
# 4        Tables   12995.2915 -3.272331e+02  -2.518090e+00             11
# 5        Chairs   11572.7800  1.179374e+03   1.019093e+01             10
# 6   Furnishings    1438.1320  2.351407e+02   1.635043e+01             12
# 7   Furnishings     678.2400  1.209528e+02   1.783333e+01             12
# 8        Chairs   21870.5760  5.684342e-14   2.599082e-16              8
# 9     Bookcases   12921.6430  1.968640e+01   1.523521e-01             10
# 10      Binders   27453.3840  7.753039e+03   2.824074e+01             10
# 11        Paper    2167.3480  1.006435e+03   4.643625e+01             15
# 12        Paper    1004.6520  4.152840e+02   4.133610e+01             14
# 13      Binders    5535.5930 -2.460675e+02  -4.445188e+00             14
# 14      Binders   19823.4790  2.233505e+03   1.126697e+01              9
# 15        Paper    2141.6340  9.475260e+02   4.424313e+01             12
# 16        Paper    1105.7280  4.670992e+02   4.224359e+01             12
# 17       Labels     113.4720  4.884480e+01   4.304569e+01             12
# 18      Binders   19024.5000  7.609800e+02   4.000000e+00              9
# 19      Storage   10925.0040  1.575110e+03   1.441748e+01             10
# 20      Copiers   61599.8240  2.519993e+04   4.090909e+01              5
# 21  Accessories   13756.5360  4.425343e+03   3.216902e+01             12
# 22  Accessories   11203.7560  1.987925e+03   1.774338e+01             13
# 23      Copiers   18839.6860  6.983884e+03   3.707006e+01              7
# 24  Accessories   10822.3600  3.085033e+03   2.850610e+01             10
# 25  Accessories    1409.5300  5.362212e+02   3.804255e+01             11
# 26  Accessories     477.9300  6.470850e+01   1.353933e+01             12
# 27       Phones    8878.4000  5.155200e+02   5.806452e+00             10
# 28  Accessories    1574.0300  6.344060e+02   4.030457e+01             10
# 29       Phones    4434.9120  9.362592e+02   2.111111e+01             10
#
#     composite_score
# 0          2.201231
# 1          2.047252
# 2          2.043949
# 3          2.021729
# 4          2.014595
# 5          2.003386
# 6          1.972961
# 7          1.961837
# 8          1.961743
# 9          1.960367
# 10         2.509623
# 11         2.314288
# 12         2.190946
# 13         2.104231
# 14         2.100143
# 15         2.091109
# 16         2.054042
# 17         2.028129
# 18         2.021605
# 19         2.017487
# 20         3.257742
# 21         2.344566
# 22         2.258644
# 23         2.160099
# 24         2.103475
# 25         1.976647
# 26         1.943722
# 27         1.926675
# 28         1.917730
# 29         1.913975

# %%
# Display the bottom products based on the new adjusted composite score
worst_products_by_category = metrics_adjusted_combined.groupby('category').apply(lambda x: x.nsmallest(10, 'composite_score')).reset_index(drop=True)
worst_products_by_category[['product_name', 'category', 'subcategory', 'total_sales', 'total_profit', 'profit_margin', 'active_months', 'composite_score']]
# Out:
#                                          product_name         category  \
# 0   Bush Westfield Collection Bookcases, Dark Cher...        Furniture
# 1   Eldon Executive Woodline II Cherry Finish Desk...        Furniture
# 2   BoxOffice By Design Rectangular and Half-Moon ...        Furniture
# 3     Riverside Furniture Stanwyck Manor Table Series        Furniture
# 4    Bush Birmingham Collection Bookcase, Dark Cherry        Furniture
# 5      Anderson Hickey Conga Table Tops & Accessories        Furniture
# 6   Bush Saratoga Collection 5-Shelf Bookcase, Han...        Furniture
# 7   Atlantic Metals Mobile 2-Shelf Bookcases, Cust...        Furniture
# 8   Tenex Traditional Chairmats for Hard Floors, A...        Furniture
# 9   Office Star - Contemporary Task Swivel chair w...        Furniture
# 10  Eureka Disposable Bags for Sanitaire Vibra Gro...  Office Supplies
# 11                   Euro Pro Shark Stick Mini Vacuum  Office Supplies
# 12               Wilson Jones DublLock D-Ring Binders  Office Supplies
# 13  Honeywell Enviracaire Portable Air Cleaner for...  Office Supplies
# 14                  Sterling Rubber Bands by Alliance  Office Supplies
# 15            GBC VeloBinder Electric Binding Machine  Office Supplies
# 16    Kensington 6 Outlet SmartSocket Surge Protector  Office Supplies
# 17                    Belkin F9S820V06 8 Outlet Surge  Office Supplies
# 18  Serrated Blade or Curved Handle Hand Letter Op...  Office Supplies
# 19                     Eldon File Chest Portable File  Office Supplies
# 20                               Okidata B401 Printer       Technology
# 21  Zebra GK420t Direct Thermal/Thermal Transfer P...       Technology
# 22  Brother MFC-9340CDW LED All-In-One Printer, Co...       Technology
# 23                Epson Perfection V600 Photo Scanner       Technology
# 24                       Cisco 8961 IP Phone Charcoal       Technology
# 25                     Plantronics Single Ear Headset       Technology
# 26  Hewlett-Packard Deskjet F4180 All-in-One Color...       Technology
# 27  Epson TM-T88V Direct Thermal Printer - Monochr...       Technology
# 28          Cubify CubeX 3D Printer Double Head Print       Technology
# 29        Lexmark MarkNet N8150 Wireless Print Server       Technology
#
#     subcategory  total_sales  total_profit  profit_margin  active_months  \
# 0     Bookcases      90.8820     -190.8522    -210.000000              1
# 1   Furnishings      98.1360      -78.5088     -80.000000              2
# 2        Tables    1706.2500    -1148.4375     -67.307692              3
# 3        Tables     917.9200     -415.9325     -45.312500              2
# 4     Bookcases     825.1740     -117.8820     -14.285714              1
# 5        Tables      51.7820      -17.5145     -33.823529              2
# 6     Bookcases     119.8330      -12.6882     -10.588235              1
# 7     Bookcases     400.0268     -113.2606     -28.313253              2
# 8   Furnishings     180.4600      -46.4040     -25.714286              2
# 9        Chairs     694.1940     -158.4858     -22.830189              2
# 10   Appliances       1.6240       -4.4660    -275.000000              1
# 11   Appliances     170.7440     -325.6332    -190.714286              3
# 12      Binders       2.0250       -1.3500     -66.666667              1
# 13   Appliances     299.2080     -177.2232     -59.230769              2
# 14    Fasteners      19.7820       -3.7680     -19.047619              1
# 15      Binders     496.0180     -411.3320     -82.926829              4
# 16   Appliances     147.5280      -36.8820     -25.000000              2
# 17   Appliances     266.3360     -120.1760     -45.121951              3
# 18     Supplies      23.8640       -4.1134     -17.236842              2
# 19      Storage      79.4000        5.9550       7.500000              1
# 20     Machines     179.9910     -251.9874    -140.000000              1
# 21     Machines     703.7100     -938.2800    -133.333333              1
# 22     Machines     341.9910     -319.1916     -93.333333              1
# 23     Machines     206.9910     -172.4925     -83.333333              1
# 24     Machines     224.9370     -164.9538     -73.333333              1
# 25     Machines      29.9250      -21.9450     -73.333333              1
# 26     Machines     101.9940      -71.3958     -70.000000              1
# 27     Machines    1212.7050    -1057.2300     -87.179487              2
# 28     Machines   11099.9630    -8879.9704     -80.000000              3
# 29     Machines     723.5100     -506.4570     -70.000000              2
#
#     composite_score
# 0          0.456412
# 1          0.931255
# 2          1.036449
# 3          1.041393
# 4          1.072672
# 5          1.074374
# 6          1.075685
# 7          1.094172
# 8          1.100566
# 9          1.114492
# 10         0.260432
# 11         0.655952
# 12         0.901556
# 13         0.995528
# 14         1.048293
# 15         1.061800
# 16         1.102509
# 17         1.111509
# 18         1.125350
# 19         1.131231
# 20         0.671450
# 21         0.680327
# 22         0.815697
# 23         0.848579
# 24         0.879861
# 25         0.880892
# 26         0.890867
# 27         0.898540
# 28         0.923030
# 29         0.959619

# %% [markdown]
# ### Category Performance

# %%
# Grouping data by category and subcategory to calculate total sales, average profit margin, and total profit
category_performance = product_metrics.groupby(['category', 'subcategory']).agg(
    total_sales=('total_sales', 'sum'),
    average_profit_margin=('profit_margin', 'mean'),
    total_profit=('total_profit', 'sum')
).reset_index()

# Sorting the results by category and then by total sales within each category
category_performance.sort_values(by=['category', 'total_sales'], ascending=False, inplace=True)
category_performance
# Out:
#            category  subcategory  total_sales  average_profit_margin  \
# 16       Technology       Phones  326628.7900              12.555032
# 15       Technology     Machines  186198.6310              -2.028366
# 13       Technology  Accessories  165795.4080              21.733481
# 14       Technology      Copiers  148628.0600              34.066789
# 11  Office Supplies      Storage  222667.5580              10.303619
# 6   Office Supplies      Binders  202984.2770              10.332846
# 4   Office Supplies   Appliances  107532.1610               9.271038
# 10  Office Supplies        Paper   77601.0980              42.778508
# 12  Office Supplies     Supplies   46189.0280              11.225482
# 5   Office Supplies          Art   27014.6320              26.084450
# 7   Office Supplies    Envelopes   16370.5620              42.328076
# 9   Office Supplies       Labels   11994.7620              43.615097
# 8   Office Supplies    Fasteners    3020.6600              27.943284
# 1         Furniture       Chairs  324252.1910               5.944535
# 3         Furniture       Tables  204589.0720             -11.028706
# 0         Furniture    Bookcases  114879.9963              -9.463915
# 2         Furniture  Furnishings   91664.6840              19.423079
#
#     total_profit
# 16    43758.1530
# 15     1925.5569
# 13    41328.4531
# 14    55302.8354
# 11    21150.7772
# 6     30018.1745
# 4     18138.0054
# 10    33634.1873
# 12    -1200.6072
# 5      6498.3676
# 7      6911.5519
# 9      5305.3945
# 8       948.3236
# 1     25941.2587
# 3    -18281.5541
# 0     -3472.5560
# 2     13044.7948

# %% [markdown]
# ### Insights
#
# - **Technology**: Shows strong performance, particularly in Copiers, with high profit margins.
# - **Office Supplies**: Show diverse performance; notably, Paper and Binders have high total sales and profit margins, making them lucrative categories.
# - **Furniture**: Is mixed, with Chairs performing well in sales but low in profit margin, and Tables and Bookcases struggling with negative profit margins.

# %% [markdown]
# # Weighting Scheme:
#
# ## Sales Metrics (40% of total score)
# - Total Sales: 20%
# - Total Units Sold: 10%
# - Sales Percentage of Total: 10%
#
# ## Pricing Metrics (10% of total score)
# - Average Sale Price: 5%
# - Min/Max Sale Price Range: 5%
#
# ## Profitability Metrics (30% of total score)
# - Profit Margin: 15%
# - Average Profit Per Unit: 15%
#
# ## Operational Metrics (10% of total score)
# - Total Orders: 5%
# - Active Months: 5%
#
# ## Impact of Discounts (10% of total score)
# - Discount Impact on Sales: 5%
# - Discount Impact on Profit: 5%

# %%
# Select relevant metrics
metrics = product_metrics[['total_sales', 'total_units_sold', 'sales_percentage_of_total',
                        'average_sale_price', 'min_sale_price_per_unit', 'max_sale_price_per_unit',
                        'profit_margin', 'average_profit_per_unit', 'total_orders', 'active_months',
                        'discount_impact_on_sales', 'discount_impact_on_profit']]

# Normalize the metrics
scaler = MinMaxScaler()
normalized_metrics = scaler.fit_transform(metrics)

# Define weights (as percentages)
weights = [0.20, 0.10, 0.10, 0.05, 0.025, 0.025, 0.15, 0.15, 0.05, 0.05, 0.05, 0.05]

# Calculate the composite score
composite_scores = normalized_metrics.dot(weights)
product_metrics['extended_composite_score'] = composite_scores

# Display the updated DataFrame with new composite scores
product_metrics[['product_id', 'composite_score', 'extended_composite_score']].head()
# Out:
#         product_id  composite_score  extended_composite_score
# 0  FUR-BO-10000112         1.072672                  0.252619
# 1  FUR-BO-10000330         1.274534                  0.275937
# 2  FUR-BO-10000362         1.480955                  0.306398
# 3  FUR-BO-10000468         1.415097                  0.290639
# 4  FUR-BO-10000711         1.281772                  0.282309

# %%
# Group data by category and display the top products based on the new adjusted composite score
top_products_by_category = product_metrics.groupby('category').apply(lambda x: x.nlargest(10, 'extended_composite_score')).reset_index(drop=True)
top_products_by_category[['product_name', 'category', 'subcategory', 'total_sales', 'total_profit', 'profit_margin', 'active_months', 'composite_score', 'extended_composite_score']]
# Out:
#                                          product_name         category  \
# 0        HON 5400 Series Task Chairs for Big and Tall        Furniture
# 1                            SAFCO Arco Folding Chair        Furniture
# 2          Bretford Rectangular Conference Table Tops        Furniture
# 3   Hon Deluxe Fabric Upholstered Stacking Chairs,...        Furniture
# 4               DMI Eclipse Executive Suite Bookcases        Furniture
# 5                  Chromcraft Round Conference Tables        Furniture
# 6       Global Troy Executive Leather Low-Back Tilter        Furniture
# 7          Situations Contoured Folding Chairs, 4/Set        Furniture
# 8       Eldon Image Series Desk Accessories, Burgundy        Furniture
# 9           Global High-Back Leather Tilter, Burgundy        Furniture
# 10  Fellowes PB500 Electric Punch Plastic Comb Bin...  Office Supplies
# 11         GBC DocuBind TL300 Electric Binding System  Office Supplies
# 12   GBC Ibimaster 500 Manual ProClick Binding System  Office Supplies
# 13                                         Xerox 1881  Office Supplies
# 14              Tennsco 6- and 18-Compartment Lockers  Office Supplies
# 15                     Hot File 7-Pocket, Floor Stand  Office Supplies
# 16               Ibico EPK-21 Electric Binding System  Office Supplies
# 17  Honeywell Enviracaire Portable HEPA Air Cleane...  Office Supplies
# 18          GBC DocuBind P400 Electric Binding System  Office Supplies
# 19                 Adjustable Depth Letter/Legal Cart  Office Supplies
# 20              Canon imageCLASS 2200 Advanced Copier       Technology
# 21          Logitech G19 Programmable Gaming Keyboard       Technology
# 22  Imation 16GB Mini TravelDrive USB 2.0 Flash Drive       Technology
# 23               Hewlett Packard LaserJet 3310 Copier       Technology
# 24  Cisco TelePresence System EX90 Videoconferenci...       Technology
# 25  HP Designjet T520 Inkjet Large Format Printer ...       Technology
# 26  Plantronics CS510 - Over-the-Head monaural Wir...       Technology
# 27   3D Systems Cube Printer, 2nd Generation, Magenta       Technology
# 28                 Canon PC1060 Personal Laser Copier       Technology
# 29                            Samsung Galaxy Mega 6.3       Technology
#
#     subcategory  total_sales  total_profit  profit_margin  active_months  \
# 0        Chairs   21870.5760  5.684342e-14   2.599082e-16              8
# 1        Chairs   11572.7800  1.179374e+03   1.019093e+01             10
# 2        Tables   12995.2915 -3.272331e+02  -2.518090e+00             11
# 3        Chairs   10637.5280  1.927442e+03   1.811927e+01              7
# 4     Bookcases   12921.6430  1.968640e+01   1.523521e-01             10
# 5        Tables    8209.0590 -1.899761e+02  -2.314225e+00             11
# 6        Chairs   12975.3820  9.518620e+02   7.335907e+00              8
# 7        Chairs    3499.3140  1.987440e+02   5.679513e+00             13
# 8   Furnishings     426.5600  1.167148e+02   2.736187e+01             15
# 9        Chairs    5436.1580 -4.747414e+02  -8.733032e+00             11
# 10      Binders   27453.3840  7.753039e+03   2.824074e+01             10
# 11      Binders   19823.4790  2.233505e+03   1.126697e+01              9
# 12      Binders   19024.5000  7.609800e+02   4.000000e+00              9
# 13        Paper    2167.3480  1.006435e+03   4.643625e+01             15
# 14      Storage   10925.0040  1.575110e+03   1.441748e+01             10
# 15      Storage    8138.2320  2.016711e+03   2.478070e+01             10
# 16      Binders   15875.9160  3.345282e+03   2.107143e+01              3
# 17   Appliances   11304.4400  3.247020e+03   2.872340e+01              7
# 18      Binders   17965.0680 -1.878166e+03  -1.045455e+01              6
# 19      Storage    7730.1960  1.932549e+03   2.500000e+01              9
# 20      Copiers   61599.8240  2.519993e+04   4.090909e+01              5
# 21  Accessories   13756.5360  4.425343e+03   3.216902e+01             12
# 22  Accessories   11203.7560  1.987925e+03   1.774338e+01             13
# 23      Copiers   18839.6860  6.983884e+03   3.707006e+01              7
# 24     Machines   22638.4800 -1.811078e+03  -8.000000e+00              1
# 25     Machines   18374.8950  4.094977e+03   2.228571e+01              3
# 26  Accessories   10822.3600  3.085033e+03   2.850610e+01             10
# 27     Machines   14299.8900  3.717971e+03   2.600000e+01              2
# 28      Copiers   11619.8340  4.570935e+03   3.933735e+01              4
# 29       Phones   13271.6840  1.772358e+03   1.335443e+01              5
#
#     composite_score  extended_composite_score
# 0          1.961743                  0.460810
# 1          2.003386                  0.434761
# 2          2.014595                  0.428745
# 3          1.820263                  0.419581
# 4          1.960367                  0.418142
# 5          1.941549                  0.414432
# 6          1.867839                  0.408840
# 7          2.043949                  0.401438
# 8          2.201231                  0.396670
# 9          1.868427                  0.391184
# 10         2.509623                  0.542334
# 11         2.100143                  0.469651
# 12         2.021605                  0.459380
# 13         2.314288                  0.439420
# 14         2.017487                  0.420769
# 15         2.017090                  0.419640
# 16         1.670277                  0.417398
# 17         1.902438                  0.414302
# 18         1.668204                  0.407016
# 19         1.937243                  0.404761
# 20         3.257742                  0.841353
# 21         2.344566                  0.484681
# 22         2.258644                  0.479278
# 23         2.160099                  0.476479
# 24         1.396452                  0.451389
# 25         1.736580                  0.442183
# 26         2.103475                  0.423801
# 27         1.599363                  0.414710
# 28         1.764778                  0.401866
# 29         1.700957                  0.399718

# %%
# Specify the path for the new CSV file
output_file_path = '../data/product_metrics.csv'

# Write the dataset to a new CSV file
product_metrics.to_csv(output_file_path, index=False)

output_file_path
# Out:
# '../data/product_metrics.csv'

# %%
product_metrics
# Out:
#            product_id                                       product_name  \
# 0     FUR-BO-10000112   Bush Birmingham Collection Bookcase, Dark Cherry
# 1     FUR-BO-10000330  Sauder Camden County Barrister Bookcase, Plank...
# 2     FUR-BO-10000362                 Sauder Inglewood Library Bookcases
# 3     FUR-BO-10000468            O'Sullivan 2-Shelf Heavy-Duty Bookcases
# 4     FUR-BO-10000711                          Hon Metal Bookcases, Gray
# ...               ...                                                ...
# 1855  TEC-PH-10004912                  Cisco SPA112 2 Port Phone Adapter
# 1856  TEC-PH-10004922             RCA Visys Integrated PBX 8-Line Router
# 1857  TEC-PH-10004924  SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x...
# 1858  TEC-PH-10004959             Classic Ivory Antique Telephone ZL1810
# 1859  TEC-PH-10004977                                        GE 30524EE4
#
#         category subcategory  total_sales  total_units_sold  \
# 0      Furniture   Bookcases      825.174                 9
# 1      Furniture   Bookcases     1064.624                10
# 2      Furniture   Bookcases     2154.348                14
# 3      Furniture   Bookcases      723.842                21
# 4      Furniture   Bookcases      851.760                12
# ...          ...         ...          ...               ...
# 1855  Technology      Phones      516.530                11
# 1856  Technology      Phones     1085.238                19
# 1857  Technology      Phones       56.164                 8
# 1858  Technology      Phones      341.666                 4
# 1859  Technology      Phones     5291.730                32
#
#       average_sale_price  min_sale_price_per_unit  max_sale_price_per_unit  \
# 0             825.174000                   91.686                   91.686
# 1             354.874667                  102.833                  120.980
# 2             430.869600                  119.686                  170.980
# 3             120.640333                   14.574                   48.580
# 4             425.880000                   70.980                   70.980
# ...                  ...                      ...                      ...
# 1855          172.176667                   43.960                   54.950
# 1856          217.047600                   53.592                   66.990
# 1857           18.721333                    5.912                    7.390
# 1858          170.833000                   80.392                  100.490
# 1859          587.970000                  117.594                  195.990
#
#       avg_sale_price_per_unit  total_profit  average_discount  \
# 0                   91.686000     -117.8820          0.300000
# 1                  108.882000       24.1960          0.100000
# 2                  148.752600      311.1836          0.130000
# 3                   39.673667     -133.1092          0.183333
# 4                   70.980000      229.9752          0.000000
# ...                       ...           ...               ...
# 1855                47.623333       87.3705          0.133333
# 1856                58.951200      130.6305          0.120000
# 1857                 6.897333       13.0064          0.066667
# 1858                90.441000       40.1960          0.100000
# 1859               165.502667      838.8372          0.155556
#
#       average_processing_time  total_returns  total_loss  profit_margin  \
# 0                    2.000000              0   -117.8820     -14.285714
# 1                    1.666667              0     -9.6784       2.272727
# 2                    4.000000              0    -35.9058      14.444444
# 3                    3.666667              0   -195.2916     -18.389262
# 4                    6.500000              0      0.0000      27.000000
# ...                       ...            ...         ...            ...
# 1855                 3.333333              0      0.0000      16.914894
# 1856                 4.000000              0      0.0000      12.037037
# 1857                 2.333333              0      0.0000      23.157895
# 1858                 3.000000              0      0.0000      11.764706
# 1859                 2.666667              0    -43.1178      15.851852
#
#       total_orders  average_profit_per_unit  sales_percentage_of_total  \
# 0                1               -13.098000                   0.036223
# 1                3                 2.419600                   0.046735
# 2                5                22.227400                   0.094571
# 3                6                -6.338533                   0.031775
# 4                2                19.164600                   0.037391
# ...            ...                      ...                        ...
# 1855             3                 7.942773                   0.022675
# 1856             5                 6.875289                   0.047640
# 1857             3                 1.625800                   0.002465
# 1858             2                10.049000                   0.014998
# 1859             9                26.213662                   0.232296
#
#       profit_rank  sales_rank  discount_impact_on_sales  \
# 0          1740.0       570.0                 35.841523
# 1          1152.0       499.0                 75.260182
# 2           268.0       283.0                254.652369
# 3          1751.0       602.0                 19.160080
# 4           337.0       560.0                 40.218155
# ...           ...         ...                       ...
# 1855        639.0       723.0                -14.967968
# 1856        481.0       491.0                 78.653694
# 1857       1351.0      1603.0                -90.754188
# 1858        974.0       882.0                -43.754372
# 1859         89.0       101.0                771.133438
#
#       discount_impact_on_profit  active_months  composite_score  \
# 0                   -156.782664              1         1.072672
# 1                    -88.345012              3         1.274534
# 2                     49.894247              5         1.480955
# 3                   -164.117464              6         1.415097
# 4                     10.776916              2         1.281772
# ...                         ...            ...              ...
# 1855                 -57.914442              3         1.312543
# 1856                 -37.076502              5         1.450893
# 1857                 -93.734938              3         1.322096
# 1858                 -80.637960              2         1.221045
# 1859                 304.060082              8         1.765987
#
#       extended_composite_score
# 0                     0.252619
# 1                     0.275937
# 2                     0.306398
# 3                     0.290639
# 4                     0.282309
# ...                        ...
# 1855                  0.279644
# 1856                  0.300439
# 1857                  0.276023
# 1858                  0.264626
# 1859                  0.363645
#
# [1860 rows x 26 columns]

# %%
# Check to see if any merging operations have introduced duplicate raws
product_metrics['product_id'].value_counts()
# Out:
# product_id
# FUR-BO-10000112    1
# OFF-PA-10003883    1
# OFF-PA-10004071    1
# OFF-PA-10004041    1
# OFF-PA-10004040    1
#                   ..
# OFF-AR-10004269    1
# OFF-AR-10004260    1
# OFF-AR-10004165    1
# OFF-AR-10004078    1
# TEC-PH-10004977    1
# Name: count, Length: 1860, dtype: int64
